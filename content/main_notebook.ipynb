# %% [markdown]
# # Analyse des GTFS (trouver meilleur titre)

# %% [markdown]
# Ce notebook sert à explorer les données GTFS blablabla...

# %%
import os
import sys
from pathlib import Path
import pandas as pd
import gtfs_kit as gk
import folium

sys.path.append('..')

from main import (
    charger_gtfs,
    obtenir_service_ids_pour_date,
    afficher_statistiques,
    exporter_resultats,
    carte_arrets,
)

# %%
# Saisir la date pour laquelle on veut récupérer les données :
DATE_ANALYSE = "20251125"  # Format AAAAMMJJ

# %%
# Charger les GTFS à analayser
GTFS_ZIP_PATH = "../data/TAM_MMM_GTFS.zip" # à modifier selon le GTFS à analyser

feed = charger_gtfs(GTFS_ZIP_PATH)
# Out:
# Chargement du fichier GTFS : ../data/TAM_MMM_GTFS.zip
# ✓ GTFS chargé avec succès

# %% [markdown]
# La cellule suivante défini la routine de création des indicateurs. \
# Vous pouvez la déplier et la modifier en fonction de vos besoins.

# %%
def calculer_indicateurs_arrets(feed, date_str):
    """
    Calcule les indicateurs pour chaque arrêt :
    - Nombre de lignes desservies
    - Nombre de passages
    - Heure du premier départ
    - Heure du dernier départ
    - Amplitude horaire
    - Temps d'attente moyen, min et max
    """
    print(f"\nCalcul des indicateurs pour le {date_str}...")

    # Récupérer les services actifs
    service_ids = obtenir_service_ids_pour_date(feed, date_str)

    if not service_ids:
        print("⚠ Aucun service actif pour cette date")
        return None

    # Filtrer les trips actifs ce jour-là
    trips_actifs = feed.trips[feed.trips["service_id"].isin(service_ids)]
    print(f"✓ {len(trips_actifs)} trips actifs")

    # Joindre avec stop_times
    stop_times_actifs = feed.stop_times.merge(
        trips_actifs[["trip_id", "service_id"]], on="trip_id"
    )

    # Calculer les indicateurs par arrêt
    indicateurs = (
        stop_times_actifs.groupby("stop_id")
        .agg(
            nombre_passages=("trip_id", "count"),
            premier_depart=("departure_time", "min"),
            dernier_depart=("departure_time", "max"),
        )
        .reset_index()
    )


    # Utilisation de gtfs_kit pour calculer les stats de headway
    indic_gk = feed.compute_stop_stats([date_str])
    indicateurs = indicateurs.merge(
        indic_gk[["stop_id", "mean_headway", "max_headway", "num_routes"]],
        on="stop_id",
        how="left",
    )
    indicateurs.rename(columns={
        "num_routes": "nb_lignes",
        "mean_headway": "temps_attente_moyen",
        "max_headway": "temps_attente_max"
    }, inplace=True)
 
    # Joindre avec les informations des arrêts
    indicateurs = indicateurs.merge(
        feed.stops[["stop_id", "stop_name", "stop_lat", "stop_lon"]],
        on="stop_id",
        how="left",
    )

    # Calculer l'amplitude horaire
    indicateurs["amplitude_horaire"] = pd.to_timedelta(
        indicateurs["dernier_depart"]
    ) - pd.to_timedelta(indicateurs["premier_depart"])
    # nettoyer pour retirer le 0 days
    indicateurs["amplitude_horaire"] = indicateurs["amplitude_horaire"].apply(
        lambda x: str(x).replace("0 days ", " ").strip()
    )

    # Réorganiser les colonnes
    indicateurs = indicateurs[
        [
            "stop_id",
            "stop_name",
            "stop_lat",
            "stop_lon",
            "nb_lignes",
            "nombre_passages",
            "premier_depart",
            "dernier_depart",
            "amplitude_horaire",
            "temps_attente_moyen",
            "temps_attente_max",
        ]
    ]

    # Trier par nombre de passages décroissant
    indicateurs = indicateurs.sort_values("nombre_passages", ascending=False)

    print(f"✓ Indicateurs calculés pour {len(indicateurs)} arrêts")

    return indicateurs

indicateurs = calculer_indicateurs_arrets(feed, DATE_ANALYSE)

indicateurs.drop(columns=["stop_lat", "stop_lon"]).head()
# Out:
# Calcul des indicateurs pour le 20251125...
# ✓ Services actifs le 20251125 : 4 service(s)
# ✓ 4165 trips actifs
# ✓ Indicateurs calculés pour 1401 arrêts
#     stop_id        stop_name  nb_lignes  nombre_passages premier_depart  \
# 123    1130           Mosson        1.0              406       04:27:00
# 141    1147  Gare Saint-Roch        2.0              362       05:05:00
# 167    1170  Gare Saint-Roch        2.0              362       05:04:00
# 168    1171          Comédie        2.0              362       05:06:00
# 140    1146          Comédie        2.0              362       05:03:00
#
#     dernier_depart amplitude_horaire  temps_attente_moyen  temps_attente_max
# 123       25:48:00          21:21:00             2.372093                7.0
# 141       25:30:00          20:25:00             2.633700                6.0
# 167       25:15:00          20:11:00             2.616788                6.0
# 168       25:17:00          20:11:00             2.614545                6.0
# 140       25:28:00          20:25:00             2.637363                6.0

# %%
afficher_statistiques(indicateurs)

exporter_resultats(indicateurs, DATE_ANALYSE)
# Out:
# ======================================================================
# STATISTIQUES GLOBALES
# ======================================================================
# Nombre total d'arrêts desservis : 1401
# Nombre total de passages : 89,477
# Moyenne de passages par arrêt : 63.9
# Médiane de passages par arrêt : 41.0
#
# Arrêt le plus fréquenté : Mosson (406 passages)
# Premier départ global : 04:16:00
# Dernier départ global : 25:51:00
#
# ======================================================================
# TOP 10 DES ARRÊTS LES PLUS FRÉQUENTÉS
# ======================================================================
# stop_id                 stop_name  stop_lat  stop_lon  nombre_passages premier_depart dernier_depart amplitude_horaire  headway_moyen  headway_max
#    1130                    Mosson 43.616320  3.819787              406       04:27:00       25:48:00          21:21:00       3.162963         34.0
#    1147           Gare Saint-Roch 43.605739  3.880156              362       05:05:00       25:30:00          20:25:00       3.393352         30.0
#    1170           Gare Saint-Roch 43.605766  3.880181              362       05:04:00       25:15:00          20:11:00       3.354571         15.0
#    1171                   Comédie 43.608361  3.879732              362       05:06:00       25:17:00          20:11:00       3.354571         15.0
#    1146                   Comédie 43.608371  3.879682              362       05:03:00       25:28:00          20:25:00       3.393352         30.0
#    1163             Port Marianne 43.601565  3.899180              356       04:59:00       25:20:00          20:21:00       3.439437         37.0
#    1164 Moularès (Hôtel de Ville) 43.600738  3.895434              356       05:00:00       25:21:00          20:21:00       3.439437         37.0
#    1153 Moularès (Hôtel de Ville) 43.600730  3.895359              355       04:46:00       24:38:00          19:52:00       3.367232         17.0
#    1154             Port Marianne 43.601576  3.899625              355       04:48:00       24:40:00          19:52:00       3.367232         17.0
#    1151         Place de l'Europe 43.607187  3.893964              315       05:06:00       25:15:00          20:09:00       3.850318         21.0
#
# ✓ Résultats exportés dans : indicateurs_arrets_20251125.csv

# %%
# Première carte : arrêts et passages

carte1 = carte_arrets(indicateurs)

carte1
# Out:
# ✓ Carte des arrêts enregistrée dans : stops_map.html
# Type of m: <class 'folium.folium.Map'>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_539b80e03ebc78cbff563c8d790f59fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_539b80e03ebc78cbff563c8d790f59fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_539b80e03ebc78cbff563c8d790f59fe = L.map(
#                 &quot;map_539b80e03ebc78cbff563c8d790f59fe&quot;,
#                 {
#                     center: [43.62171901446824, 3.8744298265024986],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bc8539000fa386b876e197242a8748c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bc8539000fa386b876e197242a8748c.addTo(map_539b80e03ebc78cbff563c8d790f59fe);
#
#
#             var circle_marker_ecea859aa16f3f499094b035459ce076 = L.circleMarker(
#                 [43.6163195, 3.81978749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_539b80e03ebc78cbff563c8d790f59fe);
#
#
#         var popup_618adc62e56411eb81cdf274f3d0fa97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c37b03904a4ccb1d34566bc77662cee1 = $(`&lt;div id=&quot;html_c37b03904a4ccb1d34566bc77662cee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arrêt ID: 1130 Passages: 406&lt;/div&gt;`)[0];
#                 popup_618adc62e56411eb81cdf274f3d0fa97.setContent(html_c37b03904a4ccb1d34566bc77662cee1);
#
#
#
#         circle_marker_ecea859aa16f3f499094b035459ce076.bindPopup(popup_618adc62e56411eb81cdf274f3d0fa97)
#         ;
#
#
#
#
#             var circle_marker_b9eb5d877a137148d199e184c0513702 = L.circleMarker(
#                 [43.60573942, 3.88015572],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_539b80e03ebc78cbff563c8d790f59fe);
#
#
#         var popup_84e9bbbe6fe9b334825aa7e2a7b0bed7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eadbb200c225b4142bcc0ff96333b57 = $(`&lt;div id=&quot;html_3eadbb200c225b4142bcc0ff96333b57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arrêt ID: 1147 Passages: 362&lt;/div&gt;`)[0];
#                 popup_84e9bbbe6fe9b334825aa7e2a7b0bed7.setContent(html_3eadbb200c225b4142bcc0ff96333b57);
#
#
#
#         circle_marker_b9eb5d877a137148d199e184c0513702.bindPopup(popup_84e9bbbe6fe9b334825aa7e2a7b0bed7)
#         ;
#
#
#
#
#             var circle_marker_3ab8e7b6c9510315d30db297e352efa4 = L.circleMarker(
#                 [43.60576602, 3.88018118],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_539b80e03ebc78cbff563c8d790f59fe);
#
#
#         var popup_cead60783e47ccf5694476fd50eb1823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6de4e5aa31016756c39d601d4db15b3 = $(`&lt;div id=&quot;html_d6de4e5aa31016756c39d601d4db15b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arrêt ID: 1170 Passages: 362&lt;/div&gt;`)[0];
#                 popup_cead60783e47ccf5694476fd50eb1823.setContent(html_d6de4e5aa31016756c39d601d4db15b3);
#
#
#
#         circle_marker_3ab8e7b6c9510315d30db297e352efa4.bindPopup(popup_cead60783e47ccf5694476fd50eb1823)
#         ;
#
#
#
#
#             v
